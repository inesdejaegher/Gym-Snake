# %%
from pathlib import Path
import matplotlib.pyplot as plt
from plot_functions import plot_condition_boxplots

# Define Path to results folder
results_path = Path("../Results/Drugs_Energy_Yes_Penalty")

# %%
plot_condition_boxplots(results_path, 'ENG_PEN_FAC9')
