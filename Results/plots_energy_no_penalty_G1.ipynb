# %%
from pathlib import Path
import matplotlib.pyplot as plt
import re
import pandas as pd
import numpy as np
from plot_functions import plot_condition_boxplots, plot_condition_boxplots_grid
from plot_functions import plot_preference_ratio_by_reward, plot_penalty_vs_no_penalty_metric

# Define Path to results folder
results_path = Path("../Results/Drugs_Energy_No_Penalty_G1")

# %%
plot_condition_boxplots(results_path, 'ENG_NO_PEN_G1')

# %%
plot_condition_boxplots_grid(results_path, 'ENG_NO_PEN_G1')

# %%
plot_preference_ratio_by_reward(results_path, "ENG_NO_PEN_G1")
