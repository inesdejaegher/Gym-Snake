# %%
from pathlib import Path
import matplotlib.pyplot as plt
from plot_functions import plot_condition_boxplots

# Define Path to results folder
results_path = Path("../Results/Drugs_Energy_No_Penalty")

# %%
plot_condition_boxplots(results_path, 'ENG_NO_PEN')
# Out:
# [WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R100_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R10_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R15_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R1_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R20_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R25_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R2_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R3_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R4_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R5_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R6_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R7_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R8_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv'), WindowsPath('../Results/Drugs_Energy_No_Penalty/EVAL_DRUG_R9_ENG_NO_PEN_Q_EP15k_TIME_07_05_2026_14-57-38.csv')]
